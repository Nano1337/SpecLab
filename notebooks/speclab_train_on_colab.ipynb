# %% [markdown]
# <a href="https://colab.research.google.com/github/Nano1337/SpecLab/blob/main/speclab_train_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pytorch-lightning -U
# !pip install albumentations==0.4.6 # order of installation matters
# !pip install torchmetrics
# !pip install optuna
# !pip install wandb
# !pip install hydra-core
# !pip install PyYAML
# !pip install pyrootutils
# !pip install hydra-colorlog==1.2.0
# !pip install hydra-optuna-sweeper==1.2.0
# !pip install rich
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 235 kB 14.9 MB/s
# ...
#      |████████████████████████████████| 51 kB 7.7 MB/s
# ...

# %%
# !unzip "/content/gdrive/MyDrive/data/SRDetection Data/GLENDA_img.zip" -d /content
# !unzip "/content/gdrive/MyDrive/data/SRDetection Data/GLENDA_mask.zip" -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/GLENDA_mask/07218.png
#   inflating: /content/GLENDA_mask/07219.png
#   inflating: /content/GLENDA_mask/07220.png
#   inflating: /content/GLENDA_mask/07221.png
#   inflating: /content/GLENDA_mask/07222.png
#   inflating: /content/GLENDA_mask/07223.png
#   inflating: /content/GLENDA_mask/07224.png
#   inflating: /content/GLENDA_mask/07225.png
#   inflating: /content/GLENDA_mask/07226.png
#   inflating: /content/GLENDA_mask/07227.png
#   inflating: /content/GLENDA_mask/07228.png
#   inflating: /content/GLENDA_mask/07229.png
#   inflating: /content/GLENDA_mask/07230.png
#   inflating: /content/GLENDA_mask/07231.png
#   inflating: /content/GLENDA_mask/07232.png
#   inflating: /content/GLENDA_mask/07233.png
#   inflating: /content/GLENDA_mask/07234.png
#   inflating: /content/GLENDA_mask/07235.png
#   inflating: /content/GLENDA_mask/07236.png
#   inflating: /content/GLENDA_mask/07237.png
# ...

# %%
# !rm -r /content/SpecLab
# !git clone https://github.com/Nano1337/SpecLab.git
# Out:
# Cloning into 'SpecLab'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 142 (delta 32), reused 80 (delta 15), pack-reused 0
# Receiving objects: 100% (142/142), 54.20 KiB | 10.84 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
import sys
sys.path.append("/content/SpecLab/src")
# !python /content/SpecLab/src/train.py experiment=baseline_experiment.yaml
# Out:
# [2022-08-01 06:12:44,039][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2022-08-01 06:12:44,047][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# CONFIG
# ├── datamodule
# │   └── _target_: src.datamodules.speclab_datamodule.SpecLabDataModule
# │       img_dir: /content/GLENDA_img
# │       mask_dir: /content/GLENDA_mask
# │       batch_size: 4
# │       train_val_test_split:
# │       - 7331
# │       - 2443
# │       - 2444
# │       num_workers: 2
# │       pin_memory: true
# │
# ├── model
# │   └── _target_: src.models.speclab_module.SpecLabLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.001
# │         weight_decay: 0.0
# │       net:
# │         _target_: src.models.components.aspp.SRDetectModel
# │         drop_rate: 0.4
# │         bn_momentum: 0.1
# │         base_num_filters: 64
# │
# ├── callbacks
# │   └── model_checkpoint:
# ...
